# %%
import openai
openai.api_key = "sk-[your-key]"

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, 
    )
    return response.choices[0].message["content"]

def get_completion_from_messages(messages, model="gpt-3.5-turbo", temperature=0):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature, 
    )
    return response.choices[0].message["content"]

# %%
messages =  [  
{'role':'system', 'content':'Eres asistente que habla como Shakespeare.'},    
{'role':'user', 'content':'cuéntame un chiste'},   
{'role':'assistant', 'content':'Por qué la gallina cruzó la carretera'},   
{'role':'user', 'content':'No sé'}  ]

# %%
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# Ah, disculpa la confusión. Permíteme reformular la pregunta en un estilo más shakespeariano:
#
# Por qué la gallina se aventuró a cruzar la vía solemne. Veréis, la vía que amuebla los caminos con sus trazos delineados y sus carros veloces, fue encarada con arrojo por la pluma gallinera. Con ánimo intrépido y el deseo de explorar nuevas tierras más allá de su corral, la valiente gallina avanzó con paso decidido para llegar al otro lado. ¡Un acto de audacia digno de aplauso, sin duda alguna!
#
# Espero que esta versión más "shakespeareana" del chiste arroje algo de luz sobre el asunto.

# %%
messages =  [  
{'role':'system', 'content':'Eres un chatbot amigable.'},    
{'role':'user', 'content':'Hola, me llamo Ana.'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# ¡Hola, Ana! ¿Cómo estás hoy? ¿Hay algo en lo que pueda ayudarte?

# %%
messages =  [  
{'role':'system', 'content':'Eres un chatbot amigable.'},    
{'role':'user', 'content':'Sí, puedes recordarme, cuál es mi nombre?'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# Lo siento, pero como soy un chatbot, no tengo la capacidad de recordar información personal. No tengo acceso a tu nombre ni a ningún dato personal. Mi función es proporcionar información y brindar asistencia en la medida de mis capacidades. ¿En qué más puedo ayudarte?

# %%
messages =  [  
{'role':'system', 'content':'Eres un chatbot amigable.'},
{'role':'user', 'content':'Hola, me llamo Ana'},
{'role':'assistant', 'content': "Hola Ana!Encantado de conocerte. Te puedo ayudar con algo?"},
{'role':'user', 'content':'Sí, puedes recordarme, cuál es mi nombre?'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# Claro, tu nombre es Ana. ¿Hay algo más en lo que pueda ayudarte, Ana?

# %%
def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context) 
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600, styles={'background-color': '#F6F6F6'})))
 
    return pn.Column(*panels)

# %%
import panel as pn  # GUI
pn.extension()

panels = [] # collect display 

context = [ {'role':'system', 'content':"""
Eres OrderBot, un servicio automatizado para recoger pedidos para una pizzería. \
Primero saludas al cliente, luego recoges el pedido, \
y luego pregunta si es un recogida o una entrega. \
Espera a recoger el pedido completo, luego lo resume y comprueba \
si el cliente quiere añadir algo más. \
Si es una entrega, pide la dirección. \
Finalmente cobra el pago. \
Asegúrese de aclarar todas las opciones, extras y tamaños \
para identificar la elemento del menú. \
Responde en un estilo amigable breve y muy conversacional. \
El menú incluye \
pepperoni pizza  12.95, 10.00, 7.00 \
pizza carbonara   10.95, 9.25, 6.50 \
pizza barbacoa   11.95, 9.75, 6.75 \
patatas fritas 4.50, 3.50 \
ensalada griega 7.25 \
Toppings: \
queso 2.00, \
setas 1.50 \
salchicha 3.00 \
bacon 3.50 \
salsa de tomate 1.50 \
pimientos 1.00 \
Bebidas: \
cola 3.00, 2.00, 1.00 \
sprite 3.00, 2.00, 1.00 \
agua 5.00 \
"""} ]  # accumulate messages
inp = pn.widgets.TextInput(value="Hola", placeholder='Introducir texto aquí…')
button_conversation = pn.widgets.Button(name="Chat!")
interactive_conversation = pn.bind(collect_messages, button_conversation)
dashboard = pn.Column(
    inp,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=200),
)

dashboard
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f871c432-718b-4d5b-809c-1d517c762275'>
#   <div id="cb54d2e1-d930-4fd7-8f29-a694ce6e91fc" data-root-id="f871c432-718b-4d5b-809c-1d517c762275" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
messages =  context.copy()
messages.append(
{'role':'system', 'content':'create a json summary of the previous food order. Itemize the price for each item\
 The fields should be 1) pizza, include size 2) list of toppings 3) list of drinks, include size   4) list of sides include size  5)total price '},    
)
 #The fields should be 1) pizza, price 2) list of toppings 3) list of drinks, include size include price  4) list of sides include size include price, 5)total price '},    

response = get_completion_from_messages(messages, temperature=0)
print(response)
# Out:
# Aquí tienes un resumen de tu pedido anterior en formato JSON:
#
# {
#   "pizza": {
#     "type": "carbonara",
#     "size": "grande",
#     "price": 10.95
#   },
#   "toppings": [],
#   "drinks": [
#     {
#       "type": "agua",
#       "size": "único",
#       "price": 5.00
#     }
#   ],
#   "sides": [],
#   "total_price": 15.95
# }
#
# Si necesitas alguna modificación o tienes alguna otra pregunta, no dudes en decírmelo. ¡Gracias por tu pedido!
